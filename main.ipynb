# %% [markdown]
# # 4IM01 - Skin Lesions - Giordmaina - Bonninière

# %%
import numpy as np 
import matplotlib.pyplot as plt
import cv2
from otsu_seg import otsu
import skimage.morphology as morph
import post_processing as pp
#import shading_attenuation as sa
import blk_removal as br
from display_image import viewimgs, viewimage, mask_display
from DICE import dice
#import ____DULL_RAZOR as dr
from IPython.display import display, Markdown

# %% [markdown]
# ## Tests on the first implementation of Otsu segmentation method

# %%
im1 = cv2.imread ("images_test/img1.jpg")
im2 = cv2.imread ("images_test/img2.jpg")
im3 = cv2.imread ("images_test/img3.jpg")
im4 = cv2.imread ("images_test/img4.jpg")
im5 = cv2.imread ("images_test/img5.jpg")
im6 = cv2.imread ("images_test/img6.jpg")
im7 = cv2.imread ("images_test/img7.jpg")
im8 = cv2.imread ("images_test/img8.jpg")
im9 = cv2.imread ("images_test/img9.jpg")
im10 = cv2.imread ("images_test/img10.jpg")
im11 = cv2.imread ("images_test/img11.jpg")
im12 = cv2.imread ("images_test/img12.jpg")
im13 = cv2.imread ("images_test/img13.jpg")

# %%
mask1 = cv2.imread ("images_test/mask1.jpg")
mask2 = cv2.imread ("images_test/mask2.jpg")
mask3 = cv2.imread ("images_test/mask3.jpg")
mask4 = cv2.imread ("images_test/mask4.jpg")
mask5 = cv2.imread ("images_test/mask5.jpg")
mask6 = cv2.imread ("images_test/mask6.jpg")
mask7 = cv2.imread ("images_test/mask7.jpg")
mask8 = cv2.imread ("images_test/mask8.jpg")
mask9 = cv2.imread ("images_test/mask9.jpg")
mask10 = cv2.imread ("images_test/mask10.jpg")
mask11 = cv2.imread ("images_test/mask11.jpg")
mask12 = cv2.imread ("images_test/mask12.jpg")
mask13 = cv2.imread ("images_test/mask13.jpg")

# %%
im_gray1 = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)
im_gray2 = cv2.cvtColor(im2, cv2.COLOR_BGR2GRAY)
im_gray3 = cv2.cvtColor(im3, cv2.COLOR_BGR2GRAY)
im_gray4 = cv2.cvtColor(im4, cv2.COLOR_BGR2GRAY)
im_gray5 = cv2.cvtColor(im5, cv2.COLOR_BGR2GRAY)
im_gray6 = cv2.cvtColor(im6, cv2.COLOR_BGR2GRAY)
im_gray7 = cv2.cvtColor(im7, cv2.COLOR_BGR2GRAY)
im_gray8 = cv2.cvtColor(im8, cv2.COLOR_BGR2GRAY)
im_gray9 = cv2.cvtColor(im9, cv2.COLOR_BGR2GRAY)
im_gray10 = cv2.cvtColor(im10, cv2.COLOR_BGR2GRAY)
im_gray11 = cv2.cvtColor(im11, cv2.COLOR_BGR2GRAY)
im_gray12 = cv2.cvtColor(im12, cv2.COLOR_BGR2GRAY)
im_gray13 = cv2.cvtColor(im13, cv2.COLOR_BGR2GRAY)

# %%
#Segmentation with Otsu method only in the pipeline

t1 = otsu(im_gray1,None)
t2 = otsu(im_gray2,None)
t3 = otsu(im_gray3,None)
t4 = otsu(im_gray4,None)
t5 = otsu(im_gray5,None)
t6 = otsu(im_gray6,None)
t7 = otsu(im_gray7,None)
t8 = otsu(im_gray8,None)
t9 = otsu(im_gray9,None)
t10 = otsu(im_gray10,None)
t11 = otsu(im_gray11,None)
t12 = otsu(im_gray12,None)
t13 = otsu(im_gray13,None)

# %%
img = cv2.imread("images_test/img10.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thresh = otsu(img,None)
mask = mask_display(img,None,thresh)
viewimage(mask)

# %%
ret1, mask1 = cv2.threshold(im_gray1, t1, 255, cv2.THRESH_BINARY_INV)
viewimage(mask1)

# %%
i1 = pp.max_closing_dice(im_gray1, mask1)
print(i1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9e7ba2c739a4> in <module>
# ----> 1 i1 = pp.max_closing_dice(im_gray1, mask1)
#       2 print(i1)
#
# AttributeError: module 'post_processing' has no attribute 'max_closing_dice'

# %%
ret2, mask2 = cv2.threshold(im_gray2, t2, 255, cv2.THRESH_BINARY_INV)
viewimgs(im_gray2, mask2)

# %%
i2 = pp.max_closing_dice(im_gray2, mask2)
print(i2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-6a602e4c3938> in <module>
# ----> 1 i2 = pp.max_closing_dice(im_gray2, mask2)
#       2 print(i2)
#
# AttributeError: module 'post_processing' has no attribute 'max_closing_dice'

# %%
ret3, mask3 = cv2.threshold(im_gray3, t3, 255, cv2.THRESH_BINARY_INV)
viewimgs(im_gray3, mask3)

# %%
i3 = pp.max_closing_dice(im_gray3, mask3)
print(i3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-3c9195c2c561> in <module>
# ----> 1 i3 = pp.max_closing_dice(im_gray3, mask3)
#       2 print(i3)
#
# AttributeError: module 'post_processing' has no attribute 'max_closing_dice'

# %%
ret4, mask4 = cv2.threshold(im_gray4, t4, 255, cv2.THRESH_BINARY_INV)
viewimage(mask4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3fc7d40d8e8d> in <module>
# ----> 1 ret4, mask4 = cv2.threshold(im_gray4, t4, 255, cv2.THRESH_BINARY_INV)
#       2 viewimage(mask4)
#
# NameError: name 'cv2' is not defined

# %%
i4 = pp.max_closing_dice(im_gray4, mask4)
print(i4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-21660a735759> in <module>
# ----> 1 i4 = pp.max_closing_dice(im_gray4, mask4)
#       2 print(i4)
#
# AttributeError: module 'post_processing' has no attribute 'max_closing_dice'

# %%
ret5, mask5 = cv2.threshold(im_gray5, t5, 255, cv2.THRESH_BINARY_INV)
viewimgs(im_gray5, mask5)
viewimage(mask5)

# %%
im_gray19 = cv2.cvtColor(cv2.imread("images_test/img19.jpg"), cv2.COLOR_BGR2GRAY)
t19 = otsu(im_gray19,None)
ret19, mask19 = cv2.threshold(im_gray19, t19, 255, cv2.THRESH_BINARY_INV)
viewimage(mask19)

# %%
ret6, mask6 = cv2.threshold(im_gray6, t6, 255, cv2.THRESH_BINARY_INV)
ret7, mask7 = cv2.threshold(im_gray7, t7, 255, cv2.THRESH_BINARY_INV)
ret8, mask8 = cv2.threshold(im_gray8, t8, 255, cv2.THRESH_BINARY_INV)
ret9, mask9 = cv2.threshold(im_gray9, t9, 255, cv2.THRESH_BINARY_INV)
ret10, mask10 = cv2.threshold(im_gray10, t10, 255, cv2.THRESH_BINARY_INV)
ret11, mask11 = cv2.threshold(im_gray11, t11, 255, cv2.THRESH_BINARY_INV)
ret12, mask12 = cv2.threshold(im_gray12, t12, 255, cv2.THRESH_BINARY_INV)
ret13, mask13 = cv2.threshold(im_gray13, t13, 255, cv2.THRESH_BINARY_INV)

# %%
#Computation of the DICE index for the images test 
msk1 = cv2.imread("images_test/msk1.png", cv2.IMREAD_GRAYSCALE)
viewimgs(mask1, msk1)
dice1 = dice(mask1,msk1)
print("DICE for image 1: ", dice1)

msk2 = cv2.imread("images_test/msk2.png", cv2.IMREAD_GRAYSCALE)
viewimgs(mask2, msk2)
dice2 = dice(mask2,msk2)
print("DICE for image 2: ", dice2)

msk3 = cv2.imread("images_test/msk3.png", cv2.IMREAD_GRAYSCALE)
viewimgs(mask3, msk3)
dice3 = dice(mask3,msk3)
print("DICE for image 3: ", dice3)

msk4 = cv2.imread("images_test/msk4.png", cv2.IMREAD_GRAYSCALE)
viewimgs(mask4, msk4)
dice4 = dice(mask4,msk4)
print("DICE for image 4: ", dice4)

msk5 = cv2.imread("images_test/msk5.png", cv2.IMREAD_GRAYSCALE)
viewimgs(mask5, msk5)
dice5 = dice(mask5,msk5)
print("DICE for image 5: ", dice5)

msk6 = cv2.imread("images_test/msk6.png", cv2.IMREAD_GRAYSCALE)
viewimgs(mask6, msk6)
dice6 = dice(mask6,msk6)
print("DICE for image 6: ", dice6)

msk7 = cv2.imread("images_test/msk7.png", cv2.IMREAD_GRAYSCALE)
viewimgs(mask7, msk7)
dice7 = dice(mask7,msk7)
print("DICE for image 7: ", dice7)

msk8 = cv2.imread("images_test/msk8.png", cv2.IMREAD_GRAYSCALE) 
viewimgs(mask8, msk8)
dice8 = dice(mask8,msk8)
print("DICE for image 8: ", dice8)

msk9 = cv2.imread("images_test/msk9.png", cv2.IMREAD_GRAYSCALE)
viewimgs(mask9, msk9)
dice9 = dice(mask9,msk9)
print("DICE for image 9: ", dice9)

msk10 = cv2.imread("images_test/msk10.png", cv2.IMREAD_GRAYSCALE)
viewimgs(mask10, msk10)
dice10 = dice(mask10,msk10)
print("DICE for image 10: ", dice10)
# Out:
# DICE for image 1:  0.5134209823144532
# DICE for image 2:  0.8436236464093941
# DICE for image 3:  0.5942052940741882
# DICE for image 4:  0.5744715554050264
# DICE for image 5:  0.8779847726195018
# DICE for image 6:  0.7009878098677075
# DICE for image 7:  0.9866045254550194
# DICE for image 8:  0.8752530381450363
# DICE for image 9:  0.7971805809321781
# DICE for image 10:  0.8083436896545131

# %%
#Otsu method with pre-processing 1

#Black removal

#Parameters
tau = 150
l=5
x,y= 10,10

mask1_pp1 = br.mask_remove(im_gray1,tau,l,x,y)
tresh1_pp1 = otsu(im_gray1,mask1_pp1)
#print(f"threshold: {tresh1_pp1}")
ret,result = cv2.threshold(im_gray1,tresh1_pp1,255,cv2.THRESH_BINARY_INV)
result1_pp1 = mask_display(im_gray1,mask1_pp1,tresh1_pp1)
viewimgs(result,result1_pp1)

mask2_pp1 = br.mask_remove(im_gray2,tau,l,x,y)
tresh2_pp1 = otsu(im_gray2,mask2_pp1)
#print(f"threshold: {tresh2_pp1}")
ret,result = cv2.threshold(im_gray2,tresh2_pp1,255,cv2.THRESH_BINARY_INV)
result2_pp1 = mask_display(im_gray2,mask2_pp1,tresh2_pp1)
viewimgs(result,result2_pp1)

mask3_pp1 = br.mask_remove(im_gray3,tau,l,x,y)
tresh3_pp1 = otsu(im_gray3,mask3_pp1)
ret,result = cv2.threshold(im_gray3,tresh3_pp1,255,cv2.THRESH_BINARY_INV)
result3_pp1 = mask_display(im_gray3,mask3_pp1,tresh3_pp1)
viewimgs(result,result3_pp1)

mask4_pp1 = br.mask_remove(im_gray4,tau,l,x,y)
tresh4_pp1 = otsu(im_gray4,mask4_pp1)
ret,result = cv2.threshold(im_gray4,tresh4_pp1,255,cv2.THRESH_BINARY_INV)
result4_pp1 = mask_display(im_gray4,mask4_pp1,tresh4_pp1)
viewimgs(result,result4_pp1)

mask5_pp1 = br.mask_remove(im_gray5,tau,l,x,y)
tresh5_pp1 = otsu(im_gray5,mask5_pp1)
ret,result = cv2.threshold(im_gray5,tresh5_pp1,255,cv2.THRESH_BINARY_INV)
result5_pp1 = mask_display(im_gray5,mask5_pp1,tresh5_pp1)
viewimgs(result,result5_pp1)


mask6_pp1 = br.mask_remove(im_gray6,tau,l,x,y)
tresh6_pp1 = otsu(im_gray6,mask6_pp1)
ret,result = cv2.threshold(im_gray6,tresh6_pp1,255,cv2.THRESH_BINARY_INV)
result6_pp1 = mask_display(im_gray6,mask6_pp1,tresh6_pp1)
viewimgs(result,result6_pp1)


mask7_pp1 = br.mask_remove(im_gray7,tau,l,x,y)
tresh7_pp1 = otsu(im_gray7,mask7_pp1)
ret,result = cv2.threshold(im_gray7,tresh7_pp1,255,cv2.THRESH_BINARY_INV)
result7_pp1 = mask_display(im_gray7,mask7_pp1,tresh7_pp1)
viewimgs(result,result7_pp1)


mask8_pp1 = br.mask_remove(im_gray8,tau,l,x,y)
tresh8_pp1 = otsu(im_gray8,mask8_pp1)
ret,result = cv2.threshold(im_gray8,tresh8_pp1,255,cv2.THRESH_BINARY_INV)
result8_pp1 = mask_display(im_gray8,mask8_pp1,tresh8_pp1)
viewimgs(result,result8_pp1)

mask9_pp1 = br.mask_remove(im_gray9,tau,l,x,y)
tresh9_pp1 = otsu(im_gray9,mask9_pp1)
ret,result = cv2.threshold(im_gray9,tresh9_pp1,255,cv2.THRESH_BINARY_INV)
result9_pp1 = mask_display(im_gray9,mask9_pp1,tresh9_pp1)
viewimgs(result,result9_pp1)

mask10_pp1 = br.mask_remove(im_gray10,tau,l,x,y)
tresh10_pp1 = otsu(im_gray10,mask10_pp1)
ret,result = cv2.threshold(im_gray10,tresh10_pp1,255,cv2.THRESH_BINARY_INV)
result10_pp1 = mask_display(im_gray10,mask10_pp1,tresh10_pp1)
viewimgs(result,result10_pp1)

# %%
#Dice for pre-processing 1

dice1_pp1 = dice(result1_pp1,msk1)
dice2_pp1 = dice(result2_pp1,msk2)
dice3_pp1 = dice(result3_pp1,msk3)
dice4_pp1 = dice(result4_pp1,msk4)
dice5_pp1 = dice(result5_pp1,msk5)
dice6_pp1 = dice(result6_pp1,msk6)
dice7_pp1 = dice(result7_pp1,msk7)
dice8_pp1 = dice(result8_pp1,msk8)
dice9_pp1 = dice(result9_pp1,msk9)
dice10_pp1 = dice(result10_pp1,msk10)

# %%
#Otsu method with pre-processing 2
#Hair removal Dull Razor

# %%
#Otsu method with post-processing

#Structuring element

struct_element1 = morph.disk(40)
struct_element2 = morph.rectangle(3,10)

mask1_pp = pp.overall(mask1,struct_element1,struct_element2)
viewimgs(msk1, mask1_pp)
dice1_pp = dice(mask1_pp,msk1)  
print("DICE for image 1 after post-processing: ", dice1_pp)

mask2_pp = pp.overall(mask2,struct_element1,struct_element2)
viewimgs(msk2, mask2_pp)
dice2_pp = dice(mask2_pp,msk2)
print("DICE for image 2 after post-processing: ", dice2_pp)

mask3_pp = pp.overall(mask3,struct_element1,struct_element2)
viewimgs(msk3, mask3_pp)
dice3_pp = dice(mask3_pp,msk3)
print("DICE for image 3 after post-processing: ", dice3_pp)

mask4_pp = pp.overall(mask4,struct_element1,struct_element2)
viewimgs(msk4, mask4_pp)
dice4_pp = dice(mask4_pp,msk4)
print("DICE for image 4 after post-processing: ", dice4_pp)

mask5_pp = pp.overall(mask5,struct_element1,struct_element2)
viewimgs(msk5, mask5_pp)
dice5_pp = dice(mask5_pp,msk5)
print("DICE for image 5 after post-processing: ", dice5_pp)

mask6_pp = pp.overall(mask6,struct_element1,struct_element2)
viewimgs(msk6, mask6_pp)
dice6_pp = dice(mask6_pp,msk6)
print("DICE for image 6 after post-processing: ", dice6_pp)

mask7_pp = pp.overall(mask7,struct_element1,struct_element2)
viewimgs(msk7, mask7_pp)
dice7_pp = dice(mask7_pp,msk7)
print("DICE for image 7 after post-processing: ", dice7_pp)

mask8_pp = pp.overall(mask8,struct_element1,struct_element2)
viewimgs(msk8, mask8_pp)
dice8_pp = dice(mask8_pp,msk8)
print("DICE for image 8 after post-processing: ", dice8_pp)

mask9_pp = pp.overall(mask9,struct_element1,struct_element2)
viewimgs(msk9, mask9_pp)
dice9_pp = dice(mask9_pp,msk9)
print("DICE for image 9 after post-processing: ", dice9_pp)

mask10_pp = pp.overall(mask10,struct_element1,struct_element2)
viewimgs(msk10, mask10_pp)
dice10_pp = dice(mask10_pp,msk10)
print("DICE for image 10 after post-processing: ", dice10_pp)
# Out:
# DICE for image 1 after post-processing:  0.6004121712023273
# DICE for image 2 after post-processing:  0.8737124698272698
# DICE for image 3 after post-processing:  0.7790621258262577
# DICE for image 4 after post-processing:  0.6365751378947295
# DICE for image 5 after post-processing:  0.9510768605064432
# DICE for image 6 after post-processing:  0.8213548903913013
# DICE for image 7 after post-processing:  0.940282631068479
# DICE for image 8 after post-processing:  0.8903361026975498
# DICE for image 9 after post-processing:  0.8872865920624743
# DICE for image 10 after post-processing:  0.9046010665597827

# %%
viewimage(mask10_pp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-89dcca3ff40d> in <module>
# ----> 1 viewimage(mask10_pp)
#
# NameError: name 'viewimage' is not defined

# %%
def find_central_component(binary_img):
    # Étiquetage des composantes connexes
    num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_img, connectivity=8)
    
    # Calcul du centre de l'image
    center_x = binary_img.shape[1] // 2
    center_y = binary_img.shape[0] // 2
    
    # Initialisation de la distance minimale et de l'indice de la composante centrale
    min_distance = float('inf')
    central_label = 0
    
    # Parcours des composantes connexes pour trouver celle la plus proche du centre
    for i in range(1, num_labels):  # Ignorer le label 0 (fond)
        centroid_x, centroid_y = centroids[i]
        distance = np.sqrt((centroid_x - center_x) ** 2 + (centroid_y - center_y) ** 2)
        if distance < min_distance:
            min_distance = distance
            central_label = i
    
    # Création d'une image binaire pour la composante centrale
    central_component = np.zeros_like(binary_img, dtype=np.uint8)
    central_component[labels == central_label] = 255
    
    return central_component

# Chargement de l'image binaire
binary_img = mask6_pp

# Vérifiez que l'image est correctement chargée
if binary_img is None:
    raise ValueError("L'image n'a pas été correctement chargée.")

# Trouver la composante connexe centrale
central_component = find_central_component(binary_img)

# Affichage de la composante connexe centrale
cv2.imshow('Central Component', central_component)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Otsu method with pre-procesing 1 and post processing 1

mask1_full = pp.overall(result1_pp1,struct_element1,struct_element2)
viewimgs(msk1, mask1_full)
dice1_full = dice(mask1_full,msk1) 

mask2_full = pp.overall(result2_pp1,struct_element1,struct_element2)
viewimgs(msk2, mask2_full)
dice2_full = dice(mask2_full,msk2)

mask3_full = pp.overall(result3_pp1,struct_element1,struct_element2)
viewimgs(msk3, mask3_full)
dice3_full = dice(mask3_full,msk3)

mask4_full = pp.overall(result4_pp1,struct_element1,struct_element2)
viewimgs(msk4, mask4_full)
dice4_full = dice(mask4_full,msk4)

mask5_full = pp.overall(result5_pp1,struct_element1,struct_element2)
viewimgs(msk5, mask5_full)
dice5_full = dice(mask5_full,msk5)

mask6_full = pp.overall(result6_pp1,struct_element1,struct_element2)
viewimgs(msk6, mask6_full)
dice6_full = dice(mask6_full,msk6)

mask7_full = pp.overall(result7_pp1,struct_element1,struct_element2)
viewimgs(msk7, mask7_full)
dice7_full = dice(mask7_full,msk7)

mask8_full = pp.overall(result8_pp1,struct_element1,struct_element2)
viewimgs(msk8, mask8_full)
dice8_full = dice(mask8_full,msk8)

mask9_full = pp.overall(result9_pp1,struct_element1,struct_element2)
viewimgs(msk9, mask9_full)
dice9_full = dice(mask9_full,msk9)

mask10_full = pp.overall(result10_pp1,struct_element1,struct_element2)
viewimgs(msk10, mask10_full)
dice10_full = dice(mask10_full,msk10)

# %%
#Ablation study for the pipeline


result1 = ["Image 1",dice1, dice1_pp1, dice1_pp,dice1_full]
result2 = ["Image 2",dice2, dice2_pp1, dice2_pp, dice2_full]
result3 = ["Image 3",dice3, dice3_pp1, dice3_pp,dice3_full]
result4 = ["Image 4",dice4, dice4_pp1, dice4_pp,dice4_full]
result5 = ["Image 5",dice5, dice4_pp1, dice5_pp,dice5_full]
result6 = ["Image 6",dice6, dice5_pp1, dice6_pp,dice6_full]
result7 = ["Image7",dice7, dice6_pp1, dice7_pp,dice7_full]
result8 = ["Image 8",dice8, dice7_pp1, dice8_pp,dice8_full]
result9 = ["Image 9",dice9, dice8_pp1, dice9_pp,dice9_full]
result10 = ["Image 10",dice10, dice9_pp1, dice10_pp,dice10_full]
results = [result1, result2, result3, result4, result5, result6, result7, result8, result9, result10]



table = "| Image | Otsu | Otsu + Pre-processing 1 | Otsu + Post-processing 1 | Otsu + Pre-processing 1 + Post-processing 1 \n"
table += "| --- | --- | --- | --- | --- \n"
for result in results:
    table += "| " + " | ".join([str(r) for r in result]) + " |\n"

display(Markdown(table))
# Out:
# | Image | Otsu | Otsu + Pre-processing 1 | Otsu + Post-processing 1 | Otsu + Pre-processing 1 + Post-processing 1
# | --- | --- | --- | --- | ---
# | Image 1 | 0.5134209823144532 | 0.6320512425307814 | 0.6004121712023273 | 0.7479156474345333 |
# | Image 2 | 0.8436236464093941 | 0.8917028910478629 | 0.8737124698272698 | 0.9380985952209857 |
# | Image 3 | 0.5942052940741882 | 0.5942052940741882 | 0.7790621258262577 | 0.7790621258262577 |
# | Image 4 | 0.5744715554050264 | 0.8605290977280661 | 0.6365751378947295 | 0.9235689186928038 |
# | Image 5 | 0.8779847726195018 | 0.8605290977280661 | 0.9510768605064432 | 0.9510768605064432 |
# | Image 6 | 0.7009878098677075 | 0.8779847726195018 | 0.8213548903913013 | 0.8213548903913013 |
# | Image7 | 0.9866045254550194 | 0.7009878098677075 | 0.940282631068479 | 0.940282631068479 |
# | Image 8 | 0.8752530381450363 | 0.9866045254550194 | 0.8903361026975498 | 0.9376792148029183 |
# ...

# %%
i1,j1,k1 = pp.max_struct_element(result1_pp1,mask1)
i2,j2,k2 = pp.max_struct_element(result2_pp1,mask2)
i3,j3,k3 = pp.max_struct_element(result3_pp1,mask3)
i4,j4,k4 = pp.max_struct_element(result4_pp1,mask4)
i5,j5,k5 = pp.max_struct_element(result5_pp1,mask5)
i6,j6,k6 = pp.max_struct_element(result6_pp1,mask6)
i7,j7,k7 = pp.max_struct_element(result7_pp1,mask7)
i8,j8,k8 = pp.max_struct_element(result8_pp1,mask8)
i9,j9,k9 = pp.max_struct_element(result9_pp1,mask9)
i10,j10,k10 = pp.max_struct_element(result10_pp1,mask10)

print("The maximum structuring element for image 1 is: ", i1,j1,k1)
print("The maximum structuring element for image 2 is: ", i2,j2,k2)
print("The maximum structuring element for image 3 is: ", i3,j3,k3)
print("The maximum structuring element for image 4 is: ", i4,j4,k4)
print("The maximum structuring element for image 5 is: ", i5,j5,k5)
print("The maximum structuring element for image 6 is: ", i6,j6,k6)
print("The maximum structuring element for image 7 is: ", i7,j7,k7)
print("The maximum structuring element for image 8 is: ", i8,j8,k8)
print("The maximum structuring element for image 9 is: ", i9,j9,k9)
print("The maximum structuring element for image 10 is: ", i10,j10,k10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-b5d7443c0b79> in <module>
# ----> 1 i1,j1,k1 = pp.max_struct_element(result1_pp1,mask1)
#       2 i2,j2,k2 = pp.max_struct_element(result2_pp1,mask2)
#       3 i3,j3,k3 = pp.max_struct_element(result3_pp1,mask3)
#       4 i4,j4,k4 = pp.max_struct_element(result4_pp1,mask4)
#       5 i5,j5,k5 = pp.max_struct_element(result5_pp1,mask5)
#
# ~/Documents/Telecom/2A/IMA/ProjIMA/4im01-skinlesions-giordmainabonniniere/post_processing.py in max_struct_element(img, mask)
#      51                 struct_element1 = morph.disk(i)
#      52                 struct_element2 = morph.rectangle(j, k)
# ---> 53                 img_pp = overall(img, struct_element1, struct_element2)
#      54                 dice_score = dice(img_pp, mask)
#      55                 if dice_score > dice_max:
#
# ...
